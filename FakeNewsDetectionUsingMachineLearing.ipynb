# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
fake['label']=0

# %%
news = pd.concat([fake,true], axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','date'],axis = 1)

# %%
news.head()
# Out:
#                                                 text subject  label
# 0  Donald Trump just couldn t wish all Americans ...    News      0
# 1  House Intelligence Committee Chairman Devin Nu...    News      0
# 2  On Friday, it was revealed that former Milwauk...    News      0
# 3  On Christmas day, Donald Trump announced that ...    News      0
# 4  Pope Francis used his annual Christmas Day mes...    News      0

# %%
news = news.sample(frac=1) #reshuffling

# %%
news.head()
# Out:
#                                                     text    subject  label
# 19302  As the Pussyhat Project s flier helpfully poin...  left-news      0
# 12165  Wikileaks founder Julian Assange has clearly s...   politics      0
# 13250  Wow! This compilation of blatant blocking for ...   politics      0
# 20801  This video is so disturbing but is a great exa...  left-news      0
# 21334  VATICAN CITY (Reuters) - It is perhaps  only a...  worldnews      1

# %%
news = news.reset_index(inplace=True)

# %%
news.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1103/850933607.py in <cell line: 0>()
# ----> 1 news.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
news = pd.concat([fake,true], axis=0)
news = news.drop(['title','date'],axis = 1)
news = news.sample(frac=1)
news = news.reset_index(drop=True)

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                               text    subject  label
# 0      0  ISLAMABAD (Reuters) - Pakistan s electoral com...  worldnews      1
# 1      1  Just recently, a USA Today sports columnist sa...   politics      0
# 2      2  Vince Foster Part II?The death by barbell of d...   politics      0
# 3      3  WASHINGTON (Reuters) - The North Korean foreig...  worldnews      1
# 4      4  BERLIN (Reuters) - German Foreign Minister Sig...  worldnews      1

# %%
news.drop(['index'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1259/1860076501.py in <cell line: 0>()
# ----> 1 news.drop(['index'],axis=1,inplace=True)
#
# NameError: name 'news' is not defined

# %%
news.head()
# Out:
#                                                 text    subject  label
# 0  ISLAMABAD (Reuters) - Pakistan s electoral com...  worldnews      1
# 1  Just recently, a USA Today sports columnist sa...   politics      0
# 2  Vince Foster Part II?The death by barbell of d...   politics      0
# 3  WASHINGTON (Reuters) - The North Korean foreig...  worldnews      1
# 4  BERLIN (Reuters) - German Foreign Minister Sig...  worldnews      1

# %%
import re

# %%
def wordopt(text):
    #Convert into lowercase
    text = text.lower()

    # Remove URLs
    text = re.sub(r'https?://\S+|www\.\S+','',text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)

    # Remove newline characters
    text = re.sub(r'\n', ' ', text)

    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        islamabad reuters  pakistan s electoral commis...
# 1        just recently a usa today sports columnist sai...
# 2        vince foster part iithe death by barbell of di...
# 3        washington reuters  the north korean foreign m...
# 4        berlin reuters  german foreign minister sigmar...
#                                ...
# 44893    it sure would be nice to have a president and ...
# 44894    the protesters are breaking all the rules and ...
# 44895    chicago reuters  illinois governor on wednesda...
# 44896    just a few days ago presidentelect donald trum...
# 44897    donald trump s first debate against his democr...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape

# %%
x_test.shape

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train

# %%
xv_test

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_lr))

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train , y_train)

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier

print(classification_report(y_test, pred_dtc))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train , y_train)

# %%
predict_rfc  = rfc.predict(xv_test)

# %%
rfc.score(xv_test,y_test)

# %%
print(classification_report(y_test, predict_rfc)  )

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train , y_train)

# %%
print(classification_report(y_test, predict_rfc))

# %%
def output_label(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Real News"
    else:
        return "Unknown"

# %%
def manual_testing(news):
    testing_news = {"text": [news]} # Corrected syntax for defining dictionary
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)  # Assuming 'vectorization' is your vectori
    pred_lr = LR.predict(new_xv_test)
    # pred_dtc = dtc.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLR Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0]))

# %%
news_article = str(input())

# %%
manual_testing(news_article)
